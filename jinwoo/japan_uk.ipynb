# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./data/olympic.csv')
data
# Out:
#                         Nation           Olympic  Gold  Silver  Bronze  \
# 0                        Spain        tokyo-2020     3       8       6
# 1                   San Marino        tokyo-2020     0       1       2
# 2     United States of America        tokyo-2020    39      41      33
# 3                     Slovakia        tokyo-2020     1       2       1
# 4                        Japan        tokyo-2020    27      13      17
# ...                        ...               ...   ...     ...     ...
# 1895               Puerto Rico  lillehammer-1994     0       0       0
# 1896            Chinese Taipei  lillehammer-1994     0       0       0
# 1897                   Armenia  lillehammer-1994     0       0       0
# 1898       Trinidad and Tobago  lillehammer-1994     0       0       0
# 1899            American Samoa  lillehammer-1994     0       0       0
#
#       event_count  total  total_rank  rank  year    type
# 0              36     17          14    22  2020  summer
# ...

# %%
summer_mask = data['type'] == 'summer'
summer = data[summer_mask]

japan_mask = summer['Nation'] == 'Japan'
UK_mask = summer['Nation'] == 'Great Britain'

japan = summer[japan_mask]
UK = summer[UK_mask]

japan = japan.set_index('year')
UK = UK.set_index('year')

# %%
japan
# Out:
#      Nation       Olympic  Gold  Silver  Bronze  event_count  total  \
# year
# 2020  Japan    tokyo-2020    27      13      17           46     57
# 2016  Japan      rio-2016    12       8      21           38     41
# 2012  Japan   london-2012     7      14      17           35     38
# 2008  Japan  beijing-2008     9       8       8           35     25
# 2004  Japan   athens-2004    16       9      12           32     37
# 2000  Japan   sydney-2000     5       8       5           31     18
# 1996  Japan  atlanta-1996     3       6       5           29     14
#
#       total_rank  rank    type
# year
# 2020           5     3  summer
# 2016           6     6  summer
# 2012           6    11  summer
# 2008          10     8  summer
# 2004           6     5  summer
# 2000          12    15  summer
# 1996          17    22  summer

# %%
plt.figure(figsize=(12, 10))
sns.lineplot(x=japan.index, y=japan['Gold'], marker='o', label='Japan')
sns.lineplot(x=UK.index, y=UK['Gold'], marker='o', label='UK')
plt.axvline(x=2012, color='r', linestyle='--', linewidth=1)
plt.axvline(x=2020, color='b', linestyle='--', linewidth=1)
plt.xticks(list(range(1996, 2021, 4)))
plt.legend()
plt.grid()
plt.title('UK VS JAPAN / GLOD medals')
# Out:
# Text(0.5, 1.0, 'UK VS JAPAN / GLOD medals')

# %%
plt.figure(figsize=(12, 10))
sns.lineplot(x=japan.index, y=japan['rank'], marker='o', label='Japan')
sns.lineplot(x=UK.index, y=UK['rank'], marker='o', label='UK')
plt.axvline(x=2012, color='r', linestyle='--', linewidth=1)
plt.axvline(x=2020, color='b', linestyle='--', linewidth=1)
plt.xticks(list(range(1996, 2021, 4)))
plt.legend()
plt.grid()
plt.title('UK VS JAPAN / Ranking')
# Out:
# Text(0.5, 1.0, 'UK VS JAPAN / Ranking')

# %%
plt.figure(figsize=(12, 10))
sns.lineplot(x=japan.index, y=japan['total_rank'], marker='o', label='Japan')
sns.lineplot(x=UK.index, y=UK['total_rank'], marker='o', label='UK')
plt.axvline(x=2012, color='r', linestyle='--', linewidth=1)
plt.axvline(x=2020, color='b', linestyle='--', linewidth=1)
plt.xticks(list(range(1996, 2021, 4)))
plt.legend()
plt.grid()
plt.title('UK VS JAPAN / Total Ranking')
# Out:
# Text(0.5, 1.0, 'UK VS JAPAN / Total Ranking')

# %%
USA_mask = summer['Nation'] == 'United States of America'
USA = summer[USA_mask]
USA = USA.set_index('year')

china_mask = summer['Nation'] == 'People\'s Republic of China'
china = summer[china_mask]
china = china.set_index('year')

# %%
plt.figure(figsize=(12, 10))
sns.lineplot(x=USA.index, y=USA['Gold'], marker='o', label='USA')
sns.lineplot(x=china.index, y=china['Gold'], marker='o', label='China')
plt.xticks(list(range(1996, 2021, 4)))
plt.legend()
plt.grid()

# %%
plt.figure(figsize=(12, 10))
sns.lineplot(x=USA.index, y=USA['rank'], marker='o', label='USA')
sns.lineplot(x=china.index, y=china['rank'], marker='o', label='China')
plt.xticks(list(range(1996, 2021, 4)))
plt.legend()
plt.yticks(list(range(1, 5)))
plt.grid()

# %%
plt.figure(figsize=(12, 10))
sns.lineplot(x=USA.index, y=USA['total_rank'], marker='o', label='USA')
sns.lineplot(x=china.index, y=china['total_rank'], marker='o', label='China')
plt.xticks(list(range(1996, 2021, 4)))
plt.legend()
plt.yticks(list(range(1, 5)))
plt.grid()

# %%
plt.figure(figsize=(12, 10))
sns.lineplot(x=japan.index, y=japan['Gold'], marker='o', label='Japan')
sns.lineplot(x=china.index, y=china['Gold'], marker='o', label='China')
sns.lineplot(x=UK.index, y=UK['Gold'], marker='o', label='UK')
plt.axvline(x=2008, color='orange', linestyle='--', linewidth=1)
plt.axvline(x=2020, color='b', linestyle='--', linewidth=1)
plt.axvline(x=2012, color='g', linestyle='--', linewidth=1)
plt.xticks(list(range(1996, 2021, 4)))
plt.legend()
plt.grid()
plt.title('GLOD medals Home Advantage', size=15)
# Out:
# Text(0.5, 1.0, 'GLOD medals Home Advantage')

# %%
japan['Gold'].sort_index().diff()
# Out:
# year
# 1996     NaN
# 2000     2.0
# 2004    11.0
# 2008    -7.0
# 2012    -2.0
# 2016     5.0
# 2020    15.0
# Name: Gold, dtype: float64

# %%
china['Gold'].sort_index().diff()
# Out:
# year
# 1996     NaN
# 2000    12.0
# 2004     4.0
# 2008    16.0
# 2012   -10.0
# 2016   -12.0
# 2020    12.0
# Name: Gold, dtype: float64

# %%
UK['Gold'].sort_index().diff()
# Out:
# year
# 1996     NaN
# 2000    10.0
# 2004    -2.0
# 2008    10.0
# 2012    10.0
# 2016    -2.0
# 2020    -5.0
# Name: Gold, dtype: float64
